# %%
from sknetwork.ranking import PageRank
import pickle
from causallearn.search.ConstraintBased.PC import pc
from causallearn.utils.cit import fisherz
from collections import defaultdict
import pandas as pd
import time
import numpy as np
from sklearn.preprocessing import normalize

# %%
hts_res_dict = {}
for experiment in range(0,4):
    with open(f"../data/hts_fault_{experiment}.pkl", "rb") as f:
        s_list, X = pickle.load(f)
    ind = 0
    mapping = {}
    for service in s_list:
        x = service.split('-')
        x = x[:-2]
        x = '-'.join(x)
        mapping[ind] = x
        ind+=1
    # Start CausalRCA
    X = np.diff(X,axis=0)
    X = normalize(X,axis=0)
    start_time = time.time()
    cg = pc(X, 0.05, fisherz, False, 0, -1, verbose=True)
    adj = cg.G.graph
    pagerank = PageRank()
    scores = pagerank.fit_predict(adj.T)
    combined_pagerank = defaultdict(float)
    for service_id in range(len(scores)):
        combined_pagerank[mapping[service_id]] += scores[service_id]
    
    combined_pagerank_df = pd.DataFrame(
                list(combined_pagerank.items()), columns=["Service Type", "Combined Frequency"]
    )
    end_time = time.time()
    ####
    
    t_elapsed = end_time - start_time
    sorted_pr = combined_pagerank_df.sort_values(by="Combined Frequency", ascending=False)
    top_5 = list(sorted_pr.head(5)["Service Type"])
    hts_res_dict[experiment] = (top_5, t_elapsed)
# Out:
#   0%|          | 0/46 [00:00<?, ?it/s]
# 0 ind 1 | () with p-value 0.080454
#
# 0 dep 2 | () with p-value 0.000000
#
# 0 dep 3 | () with p-value 0.000000
#
# 0 dep 4 | () with p-value 0.000001
#
# 0 ind 5 | () with p-value 0.841473
#
# 0 ind 6 | () with p-value 0.817166
#
# 0 dep 7 | () with p-value 0.005205
#
# 0 dep 8 | () with p-value 0.000000
#
# 0 ind 9 | () with p-value 0.499620
#
# 0 dep 10 | () with p-value 0.000000
#
# 0 dep 11 | () with p-value 0.001212
#
# 0 dep 12 | () with p-value 0.001258
#
# 0 ind 13 | () with p-value 0.747682
#
# 0 dep 14 | () with p-value 0.011879
#
# 0 dep 15 | () with p-value 0.037584
#
# 0 ind 16 | () with p-value 0.813391
#
# 0 dep 17 | () with p-value 0.000000
#
# 0 dep 18 | () with p-value 0.000000
#
# 0 dep 19 | () with p-value 0.000000
#
# 0 dep 20 | () with p-value 0.000000
#
# 0 dep 21 | () with p-value 0.000000
#
# 0 ind 22 | () with p-value 0.708479
#
# 0 dep 23 | () with p-value 0.000001
#
# 0 dep 24 | () with p-value 0.000004
#
# 0 dep 25 | () with p-value 0.036731
#
# 0 dep 26 | () with p-value 0.000258
#
# 0 dep 27 | () with p-value 0.000000
#
# 0 dep 28 | () with p-value 0.000766
#
# 0 dep 29 | () with p-value 0.000000
#
# 0 ind 30 | () with p-value 0.387424
#
# 0 dep 31 | () with p-value 0.000000
#
# 0 dep 32 | () with p-value 0.000000
#
# 0 dep 33 | () with p-value 0.000000
#
# 0 ind 34 | () with p-value 0.380608
#
# 0 dep 35 | () with p-value 0.000000
#
# 0 dep 36 | () with p-value 0.000019
#
# 0 dep 37 | () with p-value 0.000000
#
# 0 dep 38 | () with p-value 0.001025
#
# 0 dep 39 | () with p-value 0.001912
#
# 0 dep 40 | () with p-value 0.000058
#
# 0 dep 41 | () with p-value 0.000000
#
# 0 dep 42 | () with p-value 0.000000
#
# 0 dep 43 | () with p-value 0.000000
#
# 0 dep 44 | () with p-value 0.000194
#
# 0 dep 45 | () with p-value 0.000494
#
# 1 ind 2 | () with p-value 0.070837
#
# 1 ind 3 | () with p-value 0.117114
#
# 1 ind 4 | () with p-value 0.302538
#
# 1 ind 5 | () with p-value 0.782885
#
# 1 dep 6 | () with p-value 0.019555
#
# 1 ind 7 | () with p-value 0.291308
#
# 1 ind 8 | () with p-value 0.263168
#
# 1 dep 9 | () with p-value 0.023189
#
# 1 ind 10 | () with p-value 0.174647
#
# 1 ind 11 | () with p-value 0.660851
#
# 1 ind 12 | () with p-value 0.934661
#
# 1 ind 13 | () with p-value 0.123035
#
# 1 ind 14 | () with p-value 0.870367
#
# 1 ind 15 | () with p-value 0.514259
#
# 1 dep 16 | () with p-value 0.000000
#
# 1 ind 17 | () with p-value 0.402801
#
# 1 ind 18 | () with p-value 0.447306
#
# 1 ind 19 | () with p-value 0.618777
#
# 1 ind 20 | () with p-value 0.514782
#
# 1 ind 21 | () with p-value 0.502081
#
# 1 dep 22 | () with p-value 0.000000
#
# 1 ind 23 | () with p-value 0.196376
#
# 1 ind 24 | () with p-value 0.212881
#
# 1 ind 25 | () with p-value 0.372151
#
# 1 ind 26 | () with p-value 0.154382
#
# 1 ind 27 | () with p-value 0.624540
#
# 1 ind 28 | () with p-value 0.592933
#
# 1 ind 29 | () with p-value 0.246977
#
# 1 ind 30 | () with p-value 0.907989
#
# 1 ind 31 | () with p-value 0.471372
#
# 1 ind 32 | () with p-value 0.592160
#
# 1 dep 33 | () with p-value 0.044769
#
# 1 ind 34 | () with p-value 0.829626
#
# 1 ind 35 | () with p-value 0.387585
#
# 1 ind 36 | () with p-value 0.129733
#
# 1 ind 37 | () with p-value 0.869224
#
# 1 ind 38 | () with p-value 0.884880
#
# 1 ind 39 | () with p-value 0.389129
#
# 1 ind 40 | () with p-value 0.200896
#
# 1 ind 41 | () with p-value 0.908726
#
# 1 ind 42 | () with p-value 0.085175
#
# 1 ind 43 | () with p-value 0.362909
#
# 1 ind 44 | () with p-value 0.411730
#
# 1 ind 45 | () with p-value 0.096882
#
# 2 dep 0 | () with p-value 0.000000
#
# 2 dep 3 | () with p-value 0.000000
#
# 2 dep 4 | () with p-value 0.000000
#
# 2 ind 5 | () with p-value 0.275245
#
# 2 ind 6 | () with p-value 0.948000
#
# 2 dep 7 | () with p-value 0.000033
#
# 2 dep 8 | () with p-value 0.000000
#
# 2 ind 9 | () with p-value 0.053003
#
# 2 dep 10 | () with p-value 0.000000
#
# 2 dep 11 | () with p-value 0.000000
#
# 2 dep 12 | () with p-value 0.000022
#
# 2 ind 13 | () with p-value 0.279458
#
# 2 dep 14 | () with p-value 0.000000
#
# 2 dep 15 | () with p-value 0.000036
#
# 2 ind 16 | () with p-value 0.096731
#
# 2 dep 17 | () with p-value 0.000000
#
# 2 dep 18 | () with p-value 0.000000
#
# 2 dep 19 | () with p-value 0.000000
#
# 2 dep 20 | () with p-value 0.000000
#
# 2 dep 21 | () with p-value 0.000000
#
# 2 ind 22 | () with p-value 0.102209
#
# 2 dep 23 | () with p-value 0.000000
#
# 2 dep 24 | () with p-value 0.000000
#
# 2 dep 25 | () with p-value 0.000065
#
# 2 dep 26 | () with p-value 0.000012
#
# 2 dep 27 | () with p-value 0.000000
#
# 2 dep 28 | () with p-value 0.000000
#
# 2 dep 29 | () with p-value 0.000000
#
# 2 ind 30 | () with p-value 0.718949
#
# 2 dep 31 | () with p-value 0.000000
#
# 2 dep 32 | () with p-value 0.000000
#
# 2 dep 33 | () with p-value 0.000000
#
# 2 dep 34 | () with p-value 0.000265
#
# 2 dep 35 | () with p-value 0.000000
#
# 2 dep 36 | () with p-value 0.000000
#
# 2 dep 37 | () with p-value 0.000000
#
# 2 dep 38 | () with p-value 0.000000
#
# 2 dep 39 | () with p-value 0.000000
#
# 2 dep 40 | () with p-value 0.000000
#
# 2 dep 41 | () with p-value 0.000000
#
# 2 dep 42 | () with p-value 0.000000
#
# 2 dep 43 | () with p-value 0.000000
#
# 2 dep 44 | () with p-value 0.000000
#
# 2 dep 45 | () with p-value 0.000001
#
# 3 dep 0 | () with p-value 0.000000
#
# 3 dep 2 | () with p-value 0.000000
#
# 3 dep 4 | () with p-value 0.000000
#
# 3 ind 5 | () with p-value 0.061742
#
# 3 ind 6 | () with p-value 0.608916
#
# 3 dep 7 | () with p-value 0.000019
#
# 3 dep 8 | () with p-value 0.000000
#
# 3 ind 9 | () with p-value 0.463055
#
# 3 dep 10 | () with p-value 0.000000
#
# 3 ind 11 | () with p-value 0.129023
#
# 3 dep 12 | () with p-value 0.001356
#
# 3 ind 13 | () with p-value 0.479638
#
# 3 dep 14 | () with p-value 0.008623
#
# 3 ind 15 | () with p-value 0.062059
#
# 3 ind 16 | () with p-value 0.157051
#
# 3 dep 17 | () with p-value 0.000000
#
# 3 dep 18 | () with p-value 0.000000
#
# 3 dep 19 | () with p-value 0.000000
#
# 3 dep 20 | () with p-value 0.000010
#
# 3 dep 21 | () with p-value 0.000000
#
# 3 ind 22 | () with p-value 0.366703
#
# 3 dep 23 | () with p-value 0.000000
#
# 3 dep 24 | () with p-value 0.000000
#
# 3 dep 25 | () with p-value 0.007181
#
# 3 dep 26 | () with p-value 0.000000
#
# 3 dep 27 | () with p-value 0.000000
#
# 3 dep 28 | () with p-value 0.000066
#
# 3 dep 29 | () with p-value 0.000000
#
# 3 ind 30 | () with p-value 0.535316
#
# 3 dep 31 | () with p-value 0.000000
#
# 3 dep 32 | () with p-value 0.000000
#
# 3 dep 33 | () with p-value 0.000000
#
# 3 ind 34 | () with p-value 0.116786
#
# 3 dep 35 | () with p-value 0.000000
#
# 3 dep 36 | () with p-value 0.000202
#
# 3 dep 37 | () with p-value 0.000000
#
# 3 dep 38 | () with p-value 0.000000
#
# 3 dep 39 | () with p-value 0.000000
#
# 3 dep 40 | () with p-value 0.000971
#
# 3 dep 41 | () with p-value 0.000000
#
# 3 dep 42 | () with p-value 0.000000
#
# 3 dep 43 | () with p-value 0.000000
#
# 3 dep 44 | () with p-value 0.000009
#
# 3 dep 45 | () with p-value 0.007341
#
# 4 dep 0 | () with p-value 0.000001
#
# 4 dep 2 | () with p-value 0.000000
#
# 4 dep 3 | () with p-value 0.000000
#
# 4 ind 5 | () with p-value 0.910407
#
# 4 ind 6 | () with p-value 0.673889
#
# 4 dep 7 | () with p-value 0.000000
#
# 4 dep 8 | () with p-value 0.000000
#
# 4 dep 9 | () with p-value 0.026778
#
# 4 dep 10 | () with p-value 0.000000
#
# 4 dep 11 | () with p-value 0.017664
#
# 4 dep 12 | () with p-value 0.000000
#
# 4 dep 13 | () with p-value 0.049108
#
# 4 ind 14 | () with p-value 0.358591
#
# 4 dep 15 | () with p-value 0.000000
#
# 4 ind 16 | () with p-value 0.193748
#
# 4 dep 17 | () with p-value 0.000000
#
# 4 dep 18 | () with p-value 0.000000
#
# 4 dep 19 | () with p-value 0.000001
#
# 4 dep 20 | () with p-value 0.000000
#
# 4 dep 21 | () with p-value 0.000000
#
# 4 ind 22 | () with p-value 0.917202
#
# 4 dep 23 | () with p-value 0.000869
#
# 4 dep 24 | () with p-value 0.000000
#
# 4 dep 25 | () with p-value 0.000000
#
# 4 dep 26 | () with p-value 0.000000
#
# 4 dep 27 | () with p-value 0.000000
#
# 4 dep 28 | () with p-value 0.003276
#
# 4 dep 29 | () with p-value 0.000046
#
# 4 ind 30 | () with p-value 0.417572
#
# 4 dep 31 | () with p-value 0.000000
#
# 4 dep 32 | () with p-value 0.000000
#
# 4 dep 33 | () with p-value 0.000000
#
# 4 ind 34 | () with p-value 0.150062
#
# 4 dep 35 | () with p-value 0.000000
#
# 4 dep 36 | () with p-value 0.000029
#
# 4 dep 37 | () with p-value 0.000000
#
# 4 ind 38 | () with p-value 0.057661
#
# 4 dep 39 | () with p-value 0.000000
#
# 4 dep 40 | () with p-value 0.003775
#
# 4 dep 41 | () with p-value 0.015989
#
# 4 dep 42 | () with p-value 0.000000
#
# 4 dep 43 | () with p-value 0.000000
#
# 4 dep 44 | () with p-value 0.000080
#
# 4 ind 45 | () with p-value 0.896059
#
# 5 ind 6 | () with p-value 0.264343
#
# 5 ind 7 | () with p-value 0.806702
#
# 5 dep 8 | () with p-value 0.013254
#
# 5 ind 9 | () with p-value 0.738390
#
# 5 ind 10 | () with p-value 0.439951
#
# 5 ind 11 | () with p-value 0.149475
#
# 5 ind 12 | () with p-value 0.198540
#
# 5 ind 13 | () with p-value 0.502742
#
# 5 ind 14 | () with p-value 0.851626
#
# 5 ind 15 | () with p-value 0.171707
#
# 5 dep 16 | () with p-value 0.000079
#
# 5 ind 17 | () with p-value 0.842173
#
# 5 ind 18 | () with p-value 0.491019
#
# 5 ind 19 | () with p-value 0.063191
#
# 5 ind 20 | () with p-value 0.905068
#
# 5 ind 21 | () with p-value 0.500360
#
# 5 ind 22 | () with p-value 0.070638
#
# 5 ind 23 | () with p-value 0.658835
#
# 5 ind 24 | () with p-value 0.390629
#
# 5 ind 25 | () with p-value 0.772092
#
# 5 ind 26 | () with p-value 0.830041
#
# 5 ind 27 | () with p-value 0.065345
#
# 5 ind 28 | () with p-value 0.140071
#
# 5 dep 29 | () with p-value 0.037851
#
# 5 ind 30 | () with p-value 0.958156
#
# 5 ind 31 | () with p-value 0.450094
#
# 5 dep 32 | () with p-value 0.006291
#
# 5 ind 33 | () with p-value 0.646386
#
# 5 ind 34 | () with p-value 0.466566
#
# 5 dep 35 | () with p-value 0.013373
#
# 5 ind 36 | () with p-value 0.392530
#
# 5 ind 37 | () with p-value 0.586579
#
# 5 ind 38 | () with p-value 0.428129
#
# 5 ind 39 | () with p-value 0.591868
#
# 5 ind 40 | () with p-value 0.638667
#
# 5 ind 41 | () with p-value 0.802515
#
# 5 ind 42 | () with p-value 0.133740
#
# 5 ind 43 | () with p-value 0.718020
#
# 5 ind 44 | () with p-value 0.610096
#
# 5 ind 45 | () with p-value 0.927065
#
# 6 dep 1 | () with p-value 0.019555
#
# 6 ind 7 | () with p-value 0.756297
#
# 6 ind 8 | () with p-value 0.636143
#
# 6 ind 9 | () with p-value 0.139220
#
# 6 ind 10 | () with p-value 0.281780
#
# 6 ind 11 | () with p-value 0.190402
#
# 6 ind 12 | () with p-value 0.939018
#
# 6 ind 13 | () with p-value 0.827720
#
# 6 ind 14 | () with p-value 0.057280
#
# 6 ind 15 | () with p-value 0.374227
#
# 6 ind 16 | () with p-value 0.076310
#
# 6 ind 17 | () with p-value 0.327796
#
# 6 ind 18 | () with p-value 0.825798
#
# 6 ind 19 | () with p-value 0.987180
#
# 6 dep 20 | () with p-value 0.026941
#
# 6 ind 21 | () with p-value 0.597264
#
# 6 dep 22 | () with p-value 0.000837
#
# 6 ind 23 | () with p-value 0.163304
#
# 6 ind 24 | () with p-value 0.721247
#
# 6 ind 25 | () with p-value 0.450419
#
# 6 ind 26 | () with p-value 0.993357
#
# 6 ind 27 | () with p-value 0.448530
#
# 6 ind 28 | () with p-value 0.308971
#
# 6 ind 29 | () with p-value 0.088914
#
# 6 ind 30 | () with p-value 0.161887
#
# 6 ind 31 | () with p-value 0.802193
#
# 6 ind 32 | () with p-value 0.087805
#
# 6 ind 33 | () with p-value 0.584065
#
# 6 ind 34 | () with p-value 0.873646
#
# 6 ind 35 | () with p-value 0.709041
#
# 6 dep 36 | () with p-value 0.033342
#
# 6 ind 37 | () with p-value 0.887762
#
# 6 ind 38 | () with p-value 0.074176
#
# 6 ind 39 | () with p-value 0.143847
#
# 6 ind 40 | () with p-value 0.309103
#
# 6 ind 41 | () with p-value 0.557678
#
# 6 ind 42 | () with p-value 0.210590
#
# 6 ind 43 | () with p-value 0.561991
#
# 6 ind 44 | () with p-value 0.391537
#
# 6 ind 45 | () with p-value 0.735883
#
# 7 dep 0 | () with p-value 0.005205
#
# 7 dep 2 | () with p-value 0.000033
#
# 7 dep 3 | () with p-value 0.000019
#
# 7 dep 4 | () with p-value 0.000000
#
# 7 dep 8 | () with p-value 0.000211
#
# 7 dep 9 | () with p-value 0.028021
#
# 7 dep 10 | () with p-value 0.000000
#
# 7 ind 11 | () with p-value 0.079671
#
# 7 dep 12 | () with p-value 0.000000
#
# 7 dep 13 | () with p-value 0.005255
#
# 7 dep 14 | () with p-value 0.030345
#
# 7 dep 15 | () with p-value 0.000000
#
# 7 dep 16 | () with p-value 0.042021
#
# 7 dep 17 | () with p-value 0.000011
#
# 7 dep 18 | () with p-value 0.000000
#
# 7 dep 19 | () with p-value 0.000435
#
# 7 dep 20 | () with p-value 0.000000
#
# 7 dep 21 | () with p-value 0.000020
#
# 7 ind 22 | () with p-value 0.950215
#
# 7 dep 23 | () with p-value 0.001397
#
# 7 dep 24 | () with p-value 0.000000
#
# 7 dep 25 | () with p-value 0.000000
#
# 7 dep 26 | () with p-value 0.000000
#
# 7 dep 27 | () with p-value 0.002932
#
# 7 dep 28 | () with p-value 0.009531
#
# 7 dep 29 | () with p-value 0.000002
#
# 7 ind 30 | () with p-value 0.132741
#
# 7 dep 31 | () with p-value 0.000000
#
# 7 dep 32 | () with p-value 0.000040
#
# 7 dep 33 | () with p-value 0.000033
#
# 7 dep 34 | () with p-value 0.010084
#
# 7 dep 35 | () with p-value 0.000003
#
# 7 ind 36 | () with p-value 0.077859
#
# 7 dep 37 | () with p-value 0.000000
#
# 7 dep 38 | () with p-value 0.000218
#
# 7 dep 39 | () with p-value 0.000018
#
# 7 dep 40 | () with p-value 0.034920
#
# 7 dep 41 | () with p-value 0.000000
#
# 7 dep 42 | () with p-value 0.000000
#
# 7 dep 43 | () with p-value 0.000000
#
# 7 dep 44 | () with p-value 0.000363
#
# 7 dep 45 | () with p-value 0.006593
#
# 8 dep 0 | () with p-value 0.000000
#
# 8 dep 2 | () with p-value 0.000000
#
# 8 dep 3 | () with p-value 0.000000
#
# 8 dep 4 | () with p-value 0.000000
#
# 8 dep 5 | () with p-value 0.013254
#
# 8 dep 7 | () with p-value 0.000211
#
# 8 dep 9 | () with p-value 0.016104
#
# 8 dep 10 | () with p-value 0.000000
#
# 8 dep 11 | () with p-value 0.000000
#
# 8 dep 12 | () with p-value 0.000397
#
# 8 ind 13 | () with p-value 0.451602
#
# 8 dep 14 | () with p-value 0.000073
#
# 8 dep 15 | () with p-value 0.004920
#
# 8 dep 16 | () with p-value 0.007487
#
# 8 dep 17 | () with p-value 0.000000
#
# 8 dep 18 | () with p-value 0.000000
#
# 8 dep 19 | () with p-value 0.000000
#
# 8 dep 20 | () with p-value 0.000000
#
# 8 dep 21 | () with p-value 0.000000
#
# 8 dep 22 | () with p-value 0.040081
#
# 8 dep 23 | () with p-value 0.000000
#
# 8 dep 24 | () with p-value 0.000000
#
# 8 dep 25 | () with p-value 0.005541
#
# 8 dep 26 | () with p-value 0.000001
#
# 8 dep 27 | () with p-value 0.000000
#
# 8 dep 28 | () with p-value 0.000000
#
# 8 dep 29 | () with p-value 0.000000
#
# 8 ind 30 | () with p-value 0.924544
#
# 8 dep 31 | () with p-value 0.000000
#
# 8 dep 32 | () with p-value 0.000000
#
# 8 dep 33 | () with p-value 0.000000
#
# 8 ind 34 | () with p-value 0.188792
#
# 8 dep 35 | () with p-value 0.000000
#
# 8 dep 36 | () with p-value 0.000000
#
# 8 dep 37 | () with p-value 0.000000
#
# 8 dep 38 | () with p-value 0.000008
#
# 8 dep 39 | () with p-value 0.000000
#
# 8 dep 40 | () with p-value 0.000000
#
# 8 dep 41 | () with p-value 0.000000
#
# 8 dep 42 | () with p-value 0.000000
#
# 8 dep 43 | () with p-value 0.000000
#
# 8 dep 44 | () with p-value 0.000000
#
# 8 dep 45 | () with p-value 0.000167
#
# 9 dep 1 | () with p-value 0.023189
#
# 9 dep 4 | () with p-value 0.026778
#
# 9 dep 7 | () with p-value 0.028021
#
# 9 dep 8 | () with p-value 0.016104
#
# 9 ind 10 | () with p-value 0.746053
#
# 9 dep 11 | () with p-value 0.000049
#
# 9 ind 12 | () with p-value 0.221579
#
# 9 ind 13 | () with p-value 0.112332
#
# 9 dep 14 | () with p-value 0.000000
#
# 9 dep 15 | () with p-value 0.007221
#
# 9 ind 16 | () with p-value 0.162586
#
# 9 ind 17 | () with p-value 0.710551
#
# 9 ind 18 | () with p-value 0.305950
#
# 9 ind 19 | () with p-value 0.560074
#
# 9 dep 20 | () with p-value 0.000006
#
# 9 dep 21 | () with p-value 0.000262
#
# 9 dep 22 | () with p-value 0.005070
#
# 9 dep 23 | () with p-value 0.000008
#
# 9 dep 24 | () with p-value 0.026991
#
# 9 dep 25 | () with p-value 0.032800
#
# 9 ind 26 | () with p-value 0.647748
#
# 9 ind 27 | () with p-value 0.611806
#
# 9 dep 28 | () with p-value 0.018646
#
# 9 dep 29 | () with p-value 0.005425
#
# 9 ind 30 | () with p-value 0.796169
#
# 9 ind 31 | () with p-value 0.344178
#
# 9 ind 32 | () with p-value 0.069391
#
# 9 ind 33 | () with p-value 0.338300
#
# 9 dep 34 | () with p-value 0.000033
#
# 9 ind 35 | () with p-value 0.716367
#
# 9 dep 36 | () with p-value 0.010524
#
# 9 dep 37 | () with p-value 0.037534
#
# 9 dep 38 | () with p-value 0.000076
#
# 9 dep 39 | () with p-value 0.000007
#
# 9 dep 40 | () with p-value 0.000000
#
# 9 dep 41 | () with p-value 0.001282
#
# 9 dep 42 | () with p-value 0.021005
#
# 9 ind 43 | () with p-value 0.864707
#
# 9 dep 44 | () with p-value 0.000072
#
# 9 dep 45 | () with p-value 0.000000
#
# 10 dep 0 | () with p-value 0.000000
#
# 10 dep 2 | () with p-value 0.000000
#
# 10 dep 3 | () with p-value 0.000000
#
# 10 dep 4 | () with p-value 0.000000
#
# 10 dep 7 | () with p-value 0.000000
#
# 10 dep 8 | () with p-value 0.000000
#
# 10 dep 11 | () with p-value 0.004902
#
# 10 dep 12 | () with p-value 0.000000
#
# 10 ind 13 | () with p-value 0.364884
#
# 10 dep 14 | () with p-value 0.015251
#
# 10 dep 15 | () with p-value 0.000000
#
# 10 dep 16 | () with p-value 0.008302
#
# 10 dep 17 | () with p-value 0.000000
#
# 10 dep 18 | () with p-value 0.000000
#
# 10 dep 19 | () with p-value 0.000000
#
# 10 dep 20 | () with p-value 0.000000
#
# 10 dep 21 | () with p-value 0.000000
#
# 10 ind 22 | () with p-value 0.061341
#
# 10 dep 23 | () with p-value 0.000000
#
# 10 dep 24 | () with p-value 0.000000
#
# 10 dep 25 | () with p-value 0.000000
#
# 10 dep 26 | () with p-value 0.000000
#
# 10 dep 27 | () with p-value 0.000000
#
# 10 dep 28 | () with p-value 0.000001
#
# 10 dep 29 | () with p-value 0.000007
#
# 10 ind 30 | () with p-value 0.451971
#
# 10 dep 31 | () with p-value 0.000000
#
# 10 dep 32 | () with p-value 0.000000
#
# 10 dep 33 | () with p-value 0.000000
#
# 10 ind 34 | () with p-value 0.409492
#
# 10 dep 35 | () with p-value 0.000000
#
# 10 dep 36 | () with p-value 0.000000
#
# 10 dep 37 | () with p-value 0.000000
#
# 10 dep 38 | () with p-value 0.000017
#
# 10 dep 39 | () with p-value 0.000000
#
# 10 dep 40 | () with p-value 0.001467
#
# 10 dep 41 | () with p-value 0.000000
#
# 10 dep 42 | () with p-value 0.000000
#
# 10 dep 43 | () with p-value 0.000000
#
# 10 dep 44 | () with p-value 0.000000
#
# 10 dep 45 | () with p-value 0.027198
#
# 11 dep 0 | () with p-value 0.001212
#
# 11 dep 2 | () with p-value 0.000000
#
# 11 dep 4 | () with p-value 0.017664
#
# 11 dep 8 | () with p-value 0.000000
#
# 11 dep 9 | () with p-value 0.000049
#
# 11 dep 10 | () with p-value 0.004902
#
# 11 dep 12 | () with p-value 0.000000
#
# 11 dep 13 | () with p-value 0.017157
#
# 11 dep 14 | () with p-value 0.000000
#
# 11 dep 15 | () with p-value 0.000000
#
# 11 ind 16 | () with p-value 0.936985
#
# 11 dep 17 | () with p-value 0.026558
#
# 11 dep 18 | () with p-value 0.000079
#
# 11 ind 19 | () with p-value 0.439709
#
# 11 dep 20 | () with p-value 0.000000
#
# 11 dep 21 | () with p-value 0.000313
#
# 11 ind 22 | () with p-value 0.184201
#
# 11 dep 23 | () with p-value 0.000000
#
# 11 dep 24 | () with p-value 0.002783
#
# 11 dep 25 | () with p-value 0.000003
#
# 11 ind 26 | () with p-value 0.907425
#
# 11 dep 27 | () with p-value 0.002661
#
# 11 dep 28 | () with p-value 0.000000
#
# 11 dep 29 | () with p-value 0.000000
#
# 11 ind 30 | () with p-value 0.571139
#
# 11 dep 31 | () with p-value 0.000043
#
# 11 dep 32 | () with p-value 0.000000
#
# 11 dep 33 | () with p-value 0.000302
#
# 11 dep 34 | () with p-value 0.000000
#
# 11 dep 35 | () with p-value 0.000000
#
# 11 dep 36 | () with p-value 0.000000
#
# 11 dep 37 | () with p-value 0.000000
#
# 11 dep 38 | () with p-value 0.000000
#
# 11 dep 39 | () with p-value 0.000000
#
# 11 dep 40 | () with p-value 0.000000
#
# 11 dep 41 | () with p-value 0.000000
#
# 11 dep 42 | () with p-value 0.000017
#
# 11 dep 43 | () with p-value 0.006532
#
# 11 dep 44 | () with p-value 0.000000
#
# 11 dep 45 | () with p-value 0.000000
#
# 12 dep 0 | () with p-value 0.001258
#
# 12 dep 2 | () with p-value 0.000022
#
# 12 dep 3 | () with p-value 0.001356
#
# 12 dep 4 | () with p-value 0.000000
#
# 12 dep 7 | () with p-value 0.000000
#
# 12 dep 8 | () with p-value 0.000397
#
# 12 dep 10 | () with p-value 0.000000
#
# 12 dep 11 | () with p-value 0.000000
#
# 12 dep 13 | () with p-value 0.000000
#
# 12 dep 14 | () with p-value 0.000003
#
# 12 dep 15 | () with p-value 0.000000
#
# 12 dep 16 | () with p-value 0.016011
#
# 12 dep 17 | () with p-value 0.015947
#
# 12 dep 18 | () with p-value 0.016584
#
# 12 ind 19 | () with p-value 0.342073
#
# 12 dep 20 | () with p-value 0.000000
#
# 12 dep 21 | () with p-value 0.000000
#
# 12 ind 22 | () with p-value 0.331893
#
# 12 dep 23 | () with p-value 0.000000
#
# 12 dep 24 | () with p-value 0.000000
#
# 12 dep 25 | () with p-value 0.000000
#
# 12 dep 26 | () with p-value 0.000000
#
# 12 dep 27 | () with p-value 0.007907
#
# 12 dep 28 | () with p-value 0.000000
#
# 12 dep 29 | () with p-value 0.000009
#
# 12 ind 30 | () with p-value 0.217418
#
# 12 dep 31 | () with p-value 0.000075
#
# 12 dep 32 | () with p-value 0.000008
#
# 12 dep 33 | () with p-value 0.012619
#
# 12 dep 34 | () with p-value 0.000000
#
# 12 dep 35 | () with p-value 0.000009
#
# 12 dep 36 | () with p-value 0.000087
#
# 12 dep 37 | () with p-value 0.000000
#
# 12 dep 38 | () with p-value 0.000000
#
# 12 dep 39 | () with p-value 0.000000
#
# 12 dep 40 | () with p-value 0.000000
#
# 12 dep 41 | () with p-value 0.000000
#
# 12 dep 42 | () with p-value 0.000010
#
# 12 dep 43 | () with p-value 0.000727
#
# 12 dep 44 | () with p-value 0.000000
#
# 12 dep 45 | () with p-value 0.000000
#
# 13 dep 4 | () with p-value 0.049108
#
# 13 dep 7 | () with p-value 0.005255
#
# 13 dep 11 | () with p-value 0.017157
#
# 13 dep 12 | () with p-value 0.000000
#
# 13 ind 14 | () with p-value 0.158105
#
# 13 dep 15 | () with p-value 0.000000
#
# 13 ind 16 | () with p-value 0.076971
#
# 13 ind 17 | () with p-value 0.729838
#
# 13 ind 18 | () with p-value 0.570998
#
# 13 ind 19 | () with p-value 0.537697
#
# 13 dep 20 | () with p-value 0.001424
#
# 13 ind 21 | () with p-value 0.587784
#
# 13 ind 22 | () with p-value 0.082341
#
# 13 ind 23 | () with p-value 0.265431
#
# 13 dep 24 | () with p-value 0.002325
#
# 13 dep 25 | () with p-value 0.000000
#
# 13 ind 26 | () with p-value 0.969651
#
# 13 ind 27 | () with p-value 0.483033
#
# 13 ind 28 | () with p-value 0.875386
#
# 13 ind 29 | () with p-value 0.083677
#
# 13 ind 30 | () with p-value 0.906284
#
# 13 ind 31 | () with p-value 0.544327
#
# 13 ind 32 | () with p-value 0.302941
#
# 13 ind 33 | () with p-value 0.336752
#
# 13 dep 34 | () with p-value 0.021201
#
# 13 ind 35 | () with p-value 0.827564
#
# 13 ind 36 | () with p-value 0.438859
#
# 13 ind 37 | () with p-value 0.248576
#
# 13 dep 38 | () with p-value 0.013474
#
# 13 ind 39 | () with p-value 0.287183
#
# 13 ind 40 | () with p-value 0.226097
#
# 13 ind 41 | () with p-value 0.315763
#
# 13 ind 42 | () with p-value 0.072636
#
# 13 ind 43 | () with p-value 0.716159
#
# 13 ind 44 | () with p-value 0.173046
#
# 13 ind 45 | () with p-value 0.184697
#
# 14 dep 0 | () with p-value 0.011879
#
# 14 dep 2 | () with p-value 0.000000
#
# 14 dep 3 | () with p-value 0.008623
#
# 14 dep 7 | () with p-value 0.030345
#
# 14 dep 8 | () with p-value 0.000073
#
# 14 dep 9 | () with p-value 0.000000
#
# 14 dep 10 | () with p-value 0.015251
#
# 14 dep 11 | () with p-value 0.000000
#
# 14 dep 12 | () with p-value 0.000003
#
# 14 dep 15 | () with p-value 0.000000
#
# 14 ind 16 | () with p-value 0.774230
#
# 14 dep 17 | () with p-value 0.004161
#
# 14 dep 18 | () with p-value 0.000300
#
# 14 ind 19 | () with p-value 0.329130
#
# 14 dep 20 | () with p-value 0.000000
#
# 14 dep 21 | () with p-value 0.000000
#
# 14 ind 22 | () with p-value 0.959744
#
# 14 dep 23 | () with p-value 0.000000
#
# 14 ind 24 | () with p-value 0.112598
#
# 14 dep 25 | () with p-value 0.000070
#
# 14 ind 26 | () with p-value 0.550612
#
# 14 dep 27 | () with p-value 0.004926
#
# 14 dep 28 | () with p-value 0.000000
#
# 14 dep 29 | () with p-value 0.000000
#
# 14 ind 30 | () with p-value 0.415056
#
# 14 dep 31 | () with p-value 0.000006
#
# 14 dep 32 | () with p-value 0.027471
#
# 14 dep 33 | () with p-value 0.000002
#
# 14 dep 34 | () with p-value 0.000000
#
# 14 dep 35 | () with p-value 0.000000
#
# 14 dep 36 | () with p-value 0.000000
#
# 14 dep 37 | () with p-value 0.000000
#
# 14 dep 38 | () with p-value 0.000000
#
# 14 dep 39 | () with p-value 0.000000
#
# 14 dep 40 | () with p-value 0.000000
#
# 14 dep 41 | () with p-value 0.000000
#
# 14 dep 42 | () with p-value 0.000000
#
# 14 ind 43 | () with p-value 0.776282
#
# 14 dep 44 | () with p-value 0.000000
#
# 14 dep 45 | () with p-value 0.000000
#
# 15 dep 0 | () with p-value 0.037584
#
# 15 dep 2 | () with p-value 0.000036
#
# 15 dep 4 | () with p-value 0.000000
#
# 15 dep 7 | () with p-value 0.000000
#
# 15 dep 8 | () with p-value 0.004920
#
# 15 dep 9 | () with p-value 0.007221
#
# 15 dep 10 | () with p-value 0.000000
#
# 15 dep 11 | () with p-value 0.000000
#
# 15 dep 12 | () with p-value 0.000000
#
# 15 dep 13 | () with p-value 0.000000
#
# 15 dep 14 | () with p-value 0.000000
#
# 15 ind 16 | () with p-value 0.108849
#
# 15 dep 17 | () with p-value 0.035058
#
# 15 dep 18 | () with p-value 0.000623
#
# 15 ind 19 | () with p-value 0.295648
#
# 15 dep 20 | () with p-value 0.000000
#
# 15 dep 21 | () with p-value 0.000014
#
# 15 dep 22 | () with p-value 0.034928
#
# 15 dep 23 | () with p-value 0.000000
#
# 15 dep 24 | () with p-value 0.000000
#
# 15 dep 25 | () with p-value 0.000000
#
# 15 dep 26 | () with p-value 0.000000
#
# 15 ind 27 | () with p-value 0.435367
#
# 15 dep 28 | () with p-value 0.000000
#
# 15 dep 29 | () with p-value 0.000000
#
# 15 ind 30 | () with p-value 0.253084
#
# 15 dep 31 | () with p-value 0.000035
#
# 15 dep 32 | () with p-value 0.029320
#
# 15 dep 33 | () with p-value 0.000868
#
# 15 dep 34 | () with p-value 0.000000
#
# 15 dep 35 | () with p-value 0.000000
#
# 15 dep 36 | () with p-value 0.000000
#
# 15 dep 37 | () with p-value 0.000000
#
# 15 dep 38 | () with p-value 0.000000
#
# 15 dep 39 | () with p-value 0.000000
#
# 15 dep 40 | () with p-value 0.000000
#
# 15 dep 41 | () with p-value 0.000000
#
# 15 dep 42 | () with p-value 0.000000
#
# 15 ind 43 | () with p-value 0.068921
#
# 15 dep 44 | () with p-value 0.000000
#
# 15 dep 45 | () with p-value 0.000000
#
# 16 dep 1 | () with p-value 0.000000
#
# 16 dep 5 | () with p-value 0.000079
#
# 16 dep 7 | () with p-value 0.042021
#
# 16 dep 8 | () with p-value 0.007487
#
# 16 dep 10 | () with p-value 0.008302
#
# 16 dep 12 | () with p-value 0.016011
#
# 16 ind 17 | () with p-value 0.652741
#
# 16 ind 18 | () with p-value 0.077206
#
# 16 ind 19 | () with p-value 0.067334
#
# 16 dep 20 | () with p-value 0.009509
#
# 16 ind 21 | () with p-value 0.870656
#
# 16 dep 22 | () with p-value 0.000000
#
# 16 ind 23 | () with p-value 0.230265
#
# 16 ind 24 | () with p-value 0.178713
#
# 16 ind 25 | () with p-value 0.363380
#
# 16 ind 26 | () with p-value 0.818968
#
# 16 ind 27 | () with p-value 0.409252
#
# 16 ind 28 | () with p-value 0.115250
#
# 16 ind 29 | () with p-value 0.238880
#
# 16 ind 30 | () with p-value 0.379653
#
# 16 ind 31 | () with p-value 0.464935
#
# 16 dep 32 | () with p-value 0.009931
#
# 16 ind 33 | () with p-value 0.093744
#
# 16 ind 34 | () with p-value 0.978928
#
# 16 ind 35 | () with p-value 0.218387
#
# 16 ind 36 | () with p-value 0.930542
#
# 16 ind 37 | () with p-value 0.270248
#
# 16 ind 38 | () with p-value 0.673395
#
# 16 ind 39 | () with p-value 0.892279
#
# 16 ind 40 | () with p-value 0.733570
#
# 16 ind 41 | () with p-value 0.700642
#
# 16 ind 42 | () with p-value 0.164790
#
# 16 ind 43 | () with p-value 0.571138
#
# 16 ind 44 | () with p-value 0.717713
#
# 16 ind 45 | () with p-value 0.699485
#
# 17 dep 0 | () with p-value 0.000000
#
# 17 dep 2 | () with p-value 0.000000
#
# 17 dep 3 | () with p-value 0.000000
#
# 17 dep 4 | () with p-value 0.000000
#
# 17 dep 7 | () with p-value 0.000011
#
# 17 dep 8 | () with p-value 0.000000
#
# 17 dep 10 | () with p-value 0.000000
#
# 17 dep 11 | () with p-value 0.026558
#
# 17 dep 12 | () with p-value 0.015947
#
# 17 dep 14 | () with p-value 0.004161
#
# 17 dep 15 | () with p-value 0.035058
#
# 17 dep 18 | () with p-value 0.000000
#
# 17 dep 19 | () with p-value 0.000000
#
# 17 dep 20 | () with p-value 0.000000
#
# 17 dep 21 | () with p-value 0.000000
#
# 17 ind 22 | () with p-value 0.771970
#
# 17 dep 23 | () with p-value 0.000006
#
# 17 dep 24 | () with p-value 0.000000
#
# 17 ind 25 | () with p-value 0.076650
#
# 17 dep 26 | () with p-value 0.000000
#
# 17 dep 27 | () with p-value 0.000000
#
# 17 dep 28 | () with p-value 0.000000
#
# 17 dep 29 | () with p-value 0.000018
#
# 17 ind 30 | () with p-value 0.305987
#
# 17 dep 31 | () with p-value 0.000000
#
# 17 dep 32 | () with p-value 0.000000
#
# 17 dep 33 | () with p-value 0.000000
#
# 17 ind 34 | () with p-value 0.203527
#
# 17 dep 35 | () with p-value 0.000000
#
# 17 dep 36 | () with p-value 0.000000
#
# 17 dep 37 | () with p-value 0.000000
#
# 17 dep 38 | () with p-value 0.010523
#
# 17 dep 39 | () with p-value 0.000225
#
# 17 dep 40 | () with p-value 0.000005
#
# 17 dep 41 | () with p-value 0.000000
#
# 17 dep 42 | () with p-value 0.000000
#
# 17 dep 43 | () with p-value 0.000000
#
# 17 dep 44 | () with p-value 0.000000
#
# 17 dep 45 | () with p-value 0.000922
#
# 18 dep 0 | () with p-value 0.000000
#
# 18 dep 2 | () with p-value 0.000000
#
# 18 dep 3 | () with p-value 0.000000
#
# 18 dep 4 | () with p-value 0.000000
#
# 18 dep 7 | () with p-value 0.000000
#
# 18 dep 8 | () with p-value 0.000000
#
# 18 dep 10 | () with p-value 0.000000
#
# 18 dep 11 | () with p-value 0.000079
#
# 18 dep 12 | () with p-value 0.016584
#
# 18 dep 14 | () with p-value 0.000300
#
# 18 dep 15 | () with p-value 0.000623
#
# 18 dep 17 | () with p-value 0.000000
#
# 18 dep 19 | () with p-value 0.000000
#
# 18 dep 20 | () with p-value 0.000000
#
# 18 dep 21 | () with p-value 0.000000
#
# 18 ind 22 | () with p-value 0.509298
#
# 18 dep 23 | () with p-value 0.000000
#
# 18 dep 24 | () with p-value 0.000000
#
# 18 dep 25 | () with p-value 0.000148
#
# 18 dep 26 | () with p-value 0.000000
#
# 18 dep 27 | () with p-value 0.000000
#
# 18 dep 28 | () with p-value 0.000003
#
# 18 dep 29 | () with p-value 0.000000
#
# 18 ind 30 | () with p-value 0.609395
#
# 18 dep 31 | () with p-value 0.000000
#
# 18 dep 32 | () with p-value 0.000000
#
# 18 dep 33 | () with p-value 0.000000
#
# 18 dep 34 | () with p-value 0.000004
#
# 18 dep 35 | () with p-value 0.000000
#
# 18 dep 36 | () with p-value 0.000000
#
# 18 dep 37 | () with p-value 0.000000
#
# 18 dep 38 | () with p-value 0.000110
#
# 18 dep 39 | () with p-value 0.000000
#
# 18 dep 40 | () with p-value 0.000001
#
# 18 dep 41 | () with p-value 0.000000
#
# 18 dep 42 | () with p-value 0.000000
#
# 18 dep 43 | () with p-value 0.000000
#
# 18 dep 44 | () with p-value 0.000000
#
# 18 dep 45 | () with p-value 0.000001
#
# 19 dep 0 | () with p-value 0.000000
#
# 19 dep 2 | () with p-value 0.000000
#
# 19 dep 3 | () with p-value 0.000000
#
# 19 dep 4 | () with p-value 0.000001
#
# 19 dep 7 | () with p-value 0.000435
#
# 19 dep 8 | () with p-value 0.000000
#
# 19 dep 10 | () with p-value 0.000000
#
# 19 dep 17 | () with p-value 0.000000
#
# 19 dep 18 | () with p-value 0.000000
#
# 19 ind 20 | () with p-value 0.100064
#
# 19 dep 21 | () with p-value 0.000000
#
# 19 ind 22 | () with p-value 0.612398
#
# 19 dep 23 | () with p-value 0.001522
#
# 19 dep 24 | () with p-value 0.000005
#
# 19 ind 25 | () with p-value 0.488772
#
# 19 dep 26 | () with p-value 0.000000
#
# 19 dep 27 | () with p-value 0.000000
#
# 19 ind 28 | () with p-value 0.900263
#
# 19 dep 29 | () with p-value 0.045001
#
# 19 ind 30 | () with p-value 0.383522
#
# 19 dep 31 | () with p-value 0.000000
#
# 19 dep 32 | () with p-value 0.000000
#
# 19 dep 33 | () with p-value 0.000000
#
# 19 ind 34 | () with p-value 0.107586
#
# 19 dep 35 | () with p-value 0.000000
#
# 19 dep 36 | () with p-value 0.005787
#
# 19 dep 37 | () with p-value 0.000000
#
# 19 ind 38 | () with p-value 0.353732
#
# 19 dep 39 | () with p-value 0.046837
#
# 19 ind 40 | () with p-value 0.278744
#
# 19 dep 41 | () with p-value 0.016199
#
# 19 dep 42 | () with p-value 0.000000
#
# 19 dep 43 | () with p-value 0.000000
#
# 19 ind 44 | () with p-value 0.153955
#
# 19 ind 45 | () with p-value 0.849111
#
# 20 dep 0 | () with p-value 0.000000
#
# 20 dep 2 | () with p-value 0.000000
#
# 20 dep 3 | () with p-value 0.000010
#
# 20 dep 4 | () with p-value 0.000000
#
# 20 dep 6 | () with p-value 0.026941
#
# 20 dep 7 | () with p-value 0.000000
#
# 20 dep 8 | () with p-value 0.000000
#
# 20 dep 9 | () with p-value 0.000006
#
# 20 dep 10 | () with p-value 0.000000
#
# 20 dep 11 | () with p-value 0.000000
#
# 20 dep 12 | () with p-value 0.000000
#
# 20 dep 13 | () with p-value 0.001424
#
# 20 dep 14 | () with p-value 0.000000
#
# 20 dep 15 | () with p-value 0.000000
#
# 20 dep 16 | () with p-value 0.009509
#
# 20 dep 17 | () with p-value 0.000000
#
# 20 dep 18 | () with p-value 0.000000
#
# 20 dep 21 | () with p-value 0.000000
#
# 20 dep 22 | () with p-value 0.015866
#
# 20 dep 23 | () with p-value 0.000000
#
# 20 dep 24 | () with p-value 0.000000
#
# 20 dep 25 | () with p-value 0.000000
#
# 20 dep 26 | () with p-value 0.001162
#
# 20 dep 27 | () with p-value 0.000000
#
# 20 dep 28 | () with p-value 0.000000
#
# 20 dep 29 | () with p-value 0.000000
#
# 20 ind 30 | () with p-value 0.735581
#
# 20 dep 31 | () with p-value 0.000000
#
# 20 dep 32 | () with p-value 0.000000
#
# 20 dep 33 | () with p-value 0.000000
#
# 20 dep 34 | () with p-value 0.000000
#
# 20 dep 35 | () with p-value 0.000000
#
# 20 dep 36 | () with p-value 0.000000
#
# 20 dep 37 | () with p-value 0.000000
#
# 20 dep 38 | () with p-value 0.000000
#
# 20 dep 39 | () with p-value 0.000000
#
# 20 dep 40 | () with p-value 0.000000
#
# 20 dep 41 | () with p-value 0.000000
#
# 20 dep 42 | () with p-value 0.000000
#
# 20 dep 43 | () with p-value 0.000000
#
# 20 dep 44 | () with p-value 0.000000
#
# 20 dep 45 | () with p-value 0.000000
#
# 21 dep 0 | () with p-value 0.000000
#
# 21 dep 2 | () with p-value 0.000000
#
# 21 dep 3 | () with p-value 0.000000
#
# 21 dep 4 | () with p-value 0.000000
#
# 21 dep 7 | () with p-value 0.000020
#
# 21 dep 8 | () with p-value 0.000000
#
# 21 dep 9 | () with p-value 0.000262
#
# 21 dep 10 | () with p-value 0.000000
#
# 21 dep 11 | () with p-value 0.000313
#
# 21 dep 12 | () with p-value 0.000000
#
# 21 dep 14 | () with p-value 0.000000
#
# 21 dep 15 | () with p-value 0.000014
#
# 21 dep 17 | () with p-value 0.000000
#
# 21 dep 18 | () with p-value 0.000000
#
# 21 dep 19 | () with p-value 0.000000
#
# 21 dep 20 | () with p-value 0.000000
#
# 21 ind 22 | () with p-value 0.641605
#
# 21 dep 23 | () with p-value 0.000000
#
# 21 dep 24 | () with p-value 0.000000
#
# 21 dep 25 | () with p-value 0.000001
#
# 21 dep 26 | () with p-value 0.000010
#
# 21 dep 27 | () with p-value 0.000000
#
# 21 dep 28 | () with p-value 0.000000
#
# 21 dep 29 | () with p-value 0.000000
#
# 21 ind 30 | () with p-value 0.534768
#
# 21 dep 31 | () with p-value 0.000000
#
# 21 dep 32 | () with p-value 0.000000
#
# 21 dep 33 | () with p-value 0.000000
#
# 21 dep 34 | () with p-value 0.000000
#
# 21 dep 35 | () with p-value 0.000000
#
# 21 dep 36 | () with p-value 0.000000
#
# 21 dep 37 | () with p-value 0.000000
#
# 21 dep 38 | () with p-value 0.000000
#
# 21 dep 39 | () with p-value 0.000000
#
# 21 dep 40 | () with p-value 0.000000
#
# 21 dep 41 | () with p-value 0.000000
#
# 21 dep 42 | () with p-value 0.000000
#
# 21 dep 43 | () with p-value 0.000000
#
# 21 dep 44 | () with p-value 0.000000
#
# 21 dep 45 | () with p-value 0.000000
#
# 22 dep 1 | () with p-value 0.000000
#
# 22 dep 6 | () with p-value 0.000837
#
# 22 dep 8 | () with p-value 0.040081
#
# 22 dep 9 | () with p-value 0.005070
#
# 22 dep 15 | () with p-value 0.034928
#
# 22 dep 16 | () with p-value 0.000000
#
# 22 dep 20 | () with p-value 0.015866
#
# 22 ind 23 | () with p-value 0.782541
#
# 22 ind 24 | () with p-value 0.245174
#
# 22 ind 25 | () with p-value 0.454586
#
# 22 ind 26 | () with p-value 0.144414
#
# 22 ind 27 | () with p-value 0.824804
#
# 22 ind 28 | () with p-value 0.385555
#
# 22 ind 29 | () with p-value 0.739081
#
# 22 ind 30 | () with p-value 0.194633
#
# 22 ind 31 | () with p-value 0.528145
#
# 22 ind 32 | () with p-value 0.071467
#
# 22 ind 33 | () with p-value 0.098493
#
# 22 ind 34 | () with p-value 0.648580
#
# 22 ind 35 | () with p-value 0.176198
#
# 22 ind 36 | () with p-value 0.612605
#
# 22 ind 37 | () with p-value 0.872401
#
# 22 ind 38 | () with p-value 0.881693
#
# 22 ind 39 | () with p-value 0.272826
#
# 22 dep 40 | () with p-value 0.018081
#
# 22 ind 41 | () with p-value 0.365313
#
# 22 dep 42 | () with p-value 0.033425
#
# 22 ind 43 | () with p-value 0.758986
#
# 22 ind 44 | () with p-value 0.893196
#
# 22 ind 45 | () with p-value 0.107512
#
# 23 dep 0 | () with p-value 0.000001
#
# 23 dep 2 | () with p-value 0.000000
#
# 23 dep 3 | () with p-value 0.000000
#
# 23 dep 4 | () with p-value 0.000869
#
# 23 dep 7 | () with p-value 0.001397
#
# 23 dep 8 | () with p-value 0.000000
#
# 23 dep 9 | () with p-value 0.000008
#
# 23 dep 10 | () with p-value 0.000000
#
# 23 dep 11 | () with p-value 0.000000
#
# 23 dep 12 | () with p-value 0.000000
#
# 23 dep 14 | () with p-value 0.000000
#
# 23 dep 15 | () with p-value 0.000000
#
# 23 dep 17 | () with p-value 0.000006
#
# 23 dep 18 | () with p-value 0.000000
#
# 23 dep 19 | () with p-value 0.001522
#
# 23 dep 20 | () with p-value 0.000000
#
# 23 dep 21 | () with p-value 0.000000
#
# 23 dep 24 | () with p-value 0.000024
#
# 23 dep 25 | () with p-value 0.000000
#
# 23 ind 26 | () with p-value 0.056394
#
# 23 dep 27 | () with p-value 0.000000
#
# 23 dep 28 | () with p-value 0.000000
#
# 23 dep 29 | () with p-value 0.000000
#
# 23 ind 30 | () with p-value 0.444654
#
# 23 dep 31 | () with p-value 0.000000
#
# 23 dep 32 | () with p-value 0.000000
#
# 23 dep 33 | () with p-value 0.000000
#
# 23 dep 34 | () with p-value 0.000000
#
# 23 dep 35 | () with p-value 0.000000
#
# 23 dep 36 | () with p-value 0.000000
#
# 23 dep 37 | () with p-value 0.000000
#
# 23 dep 38 | () with p-value 0.000000
#
# 23 dep 39 | () with p-value 0.000000
#
# 23 dep 40 | () with p-value 0.000000
#
# 23 dep 41 | () with p-value 0.000000
#
# 23 dep 42 | () with p-value 0.000000
#
# 23 dep 43 | () with p-value 0.000000
#
# 23 dep 44 | () with p-value 0.000000
#
# 23 dep 45 | () with p-value 0.000000
#
# 24 dep 0 | () with p-value 0.000004
#
# 24 dep 2 | () with p-value 0.000000
#
# 24 dep 3 | () with p-value 0.000000
#
# 24 dep 4 | () with p-value 0.000000
#
# 24 dep 7 | () with p-value 0.000000
#
# 24 dep 8 | () with p-value 0.000000
#
# 24 dep 9 | () with p-value 0.026991
#
# 24 dep 10 | () with p-value 0.000000
#
# 24 dep 11 | () with p-value 0.002783
#
# 24 dep 12 | () with p-value 0.000000
#
# 24 dep 13 | () with p-value 0.002325
#
# 24 dep 15 | () with p-value 0.000000
#
# 24 dep 17 | () with p-value 0.000000
#
# 24 dep 18 | () with p-value 0.000000
#
# 24 dep 19 | () with p-value 0.000005
#
# 24 dep 20 | () with p-value 0.000000
#
# 24 dep 21 | () with p-value 0.000000
#
# 24 dep 23 | () with p-value 0.000024
#
# 24 dep 25 | () with p-value 0.000000
#
# 24 dep 26 | () with p-value 0.000000
#
# 24 dep 27 | () with p-value 0.000000
#
# 24 dep 28 | () with p-value 0.000536
#
# 24 dep 29 | () with p-value 0.000143
#
# 24 ind 30 | () with p-value 0.815931
#
# 24 dep 31 | () with p-value 0.000000
#
# 24 dep 32 | () with p-value 0.000000
#
# 24 dep 33 | () with p-value 0.000000
#
# 24 dep 34 | () with p-value 0.000833
#
# 24 dep 35 | () with p-value 0.000000
#
# 24 dep 36 | () with p-value 0.003769
#
# 24 dep 37 | () with p-value 0.000000
#
# 24 dep 38 | () with p-value 0.001052
#
# 24 dep 39 | () with p-value 0.000031
#
# 24 dep 40 | () with p-value 0.002568
#
# 24 dep 41 | () with p-value 0.000000
#
# 24 dep 42 | () with p-value 0.000000
#
# 24 dep 43 | () with p-value 0.000000
#
# 24 dep 44 | () with p-value 0.000018
#
# 24 dep 45 | () with p-value 0.007903
#
# 25 dep 0 | () with p-value 0.036731
#
# 25 dep 2 | () with p-value 0.000065
#
# 25 dep 3 | () with p-value 0.007181
#
# 25 dep 4 | () with p-value 0.000000
#
# 25 dep 7 | () with p-value 0.000000
#
# 25 dep 8 | () with p-value 0.005541
#
# 25 dep 9 | () with p-value 0.032800
#
# 25 dep 10 | () with p-value 0.000000
#
# 25 dep 11 | () with p-value 0.000003
#
# 25 dep 12 | () with p-value 0.000000
#
# 25 dep 13 | () with p-value 0.000000
#
# 25 dep 14 | () with p-value 0.000070
#
# 25 dep 15 | () with p-value 0.000000
#
# 25 dep 18 | () with p-value 0.000148
#
# 25 dep 20 | () with p-value 0.000000
#
# 25 dep 21 | () with p-value 0.000001
#
# 25 dep 23 | () with p-value 0.000000
#
# 25 dep 24 | () with p-value 0.000000
#
# 25 dep 26 | () with p-value 0.000053
#
# 25 ind 27 | () with p-value 0.065062
#
# 25 dep 28 | () with p-value 0.000022
#
# 25 dep 29 | () with p-value 0.000000
#
# 25 ind 30 | () with p-value 0.924447
#
# 25 dep 31 | () with p-value 0.004711
#
# 25 dep 32 | () with p-value 0.000150
#
# 25 dep 33 | () with p-value 0.019032
#
# 25 dep 34 | () with p-value 0.000000
#
# 25 dep 35 | () with p-value 0.000075
#
# 25 dep 36 | () with p-value 0.000309
#
# 25 dep 37 | () with p-value 0.000000
#
# 25 dep 38 | () with p-value 0.000011
#
# 25 dep 39 | () with p-value 0.000001
#
# 25 dep 40 | () with p-value 0.000000
#
# 25 dep 41 | () with p-value 0.000000
#
# 25 dep 42 | () with p-value 0.000000
#
# 25 dep 43 | () with p-value 0.000249
#
# 25 dep 44 | () with p-value 0.000000
#
# 25 dep 45 | () with p-value 0.000000
#
# 26 dep 0 | () with p-value 0.000258
#
# 26 dep 2 | () with p-value 0.000012
#
# 26 dep 3 | () with p-value 0.000000
#
# 26 dep 4 | () with p-value 0.000000
#
# 26 dep 7 | () with p-value 0.000000
#
# 26 dep 8 | () with p-value 0.000001
#
# 26 dep 10 | () with p-value 0.000000
#
# 26 dep 12 | () with p-value 0.000000
#
# 26 dep 15 | () with p-value 0.000000
#
# 26 dep 17 | () with p-value 0.000000
#
# 26 dep 18 | () with p-value 0.000000
#
# 26 dep 19 | () with p-value 0.000000
#
# 26 dep 20 | () with p-value 0.001162
#
# 26 dep 21 | () with p-value 0.000010
#
# 26 dep 24 | () with p-value 0.000000
#
# 26 dep 25 | () with p-value 0.000053
#
# 26 dep 27 | () with p-value 0.000000
#
# 26 ind 28 | () with p-value 0.301587
#
# 26 ind 29 | () with p-value 0.246003
#
# 26 ind 30 | () with p-value 0.695746
#
# 26 dep 31 | () with p-value 0.000000
#
# 26 dep 32 | () with p-value 0.000006
#
# 26 dep 33 | () with p-value 0.000001
#
# 26 ind 34 | () with p-value 0.125627
#
# 26 dep 35 | () with p-value 0.000000
#
# 26 ind 36 | () with p-value 0.239131
#
# 26 dep 37 | () with p-value 0.000000
#
# 26 ind 38 | () with p-value 0.628594
#
# 26 ind 39 | () with p-value 0.183917
#
# 26 ind 40 | () with p-value 0.699199
#
# 26 ind 41 | () with p-value 0.886294
#
# 26 dep 42 | () with p-value 0.000004
#
# 26 dep 43 | () with p-value 0.000000
#
# 26 ind 44 | () with p-value 0.169596
#
# 26 ind 45 | () with p-value 0.465258
#
# 27 dep 0 | () with p-value 0.000000
#
# 27 dep 2 | () with p-value 0.000000
#
# 27 dep 3 | () with p-value 0.000000
#
# 27 dep 4 | () with p-value 0.000000
#
# 27 dep 7 | () with p-value 0.002932
#
# 27 dep 8 | () with p-value 0.000000
#
# 27 dep 10 | () with p-value 0.000000
#
# 27 dep 11 | () with p-value 0.002661
#
# 27 dep 12 | () with p-value 0.007907
#
# 27 dep 14 | () with p-value 0.004926
#
# 27 dep 17 | () with p-value 0.000000
#
# 27 dep 18 | () with p-value 0.000000
#
# 27 dep 19 | () with p-value 0.000000
#
# 27 dep 20 | () with p-value 0.000000
#
# 27 dep 21 | () with p-value 0.000000
#
# 27 dep 23 | () with p-value 0.000000
#
# 27 dep 24 | () with p-value 0.000000
#
# 27 dep 26 | () with p-value 0.000000
#
# 27 dep 28 | () with p-value 0.000000
#
# 27 dep 29 | () with p-value 0.000000
#
# 27 ind 30 | () with p-value 0.886323
#
# 27 dep 31 | () with p-value 0.000000
#
# 27 dep 32 | () with p-value 0.000000
#
# 27 dep 33 | () with p-value 0.000000
#
# 27 ind 34 | () with p-value 0.092706
#
# 27 dep 35 | () with p-value 0.000000
#
# 27 dep 36 | () with p-value 0.000000
#
# 27 dep 37 | () with p-value 0.000000
#
# 27 dep 38 | () with p-value 0.000000
#
# 27 dep 39 | () with p-value 0.000000
#
# 27 dep 40 | () with p-value 0.000107
#
# 27 dep 41 | () with p-value 0.000000
#
# 27 dep 42 | () with p-value 0.000000
#
# 27 dep 43 | () with p-value 0.000000
#
# 27 dep 44 | () with p-value 0.000000
#
# 27 dep 45 | () with p-value 0.000196
#
# 28 dep 0 | () with p-value 0.000766
#
# 28 dep 2 | () with p-value 0.000000
#
# 28 dep 3 | () with p-value 0.000066
#
# 28 dep 4 | () with p-value 0.003276
#
# 28 dep 7 | () with p-value 0.009531
#
# 28 dep 8 | () with p-value 0.000000
#
# 28 dep 9 | () with p-value 0.018646
#
# 28 dep 10 | () with p-value 0.000001
#
# 28 dep 11 | () with p-value 0.000000
#
# 28 dep 12 | () with p-value 0.000000
#
# 28 dep 14 | () with p-value 0.000000
#
# 28 dep 15 | () with p-value 0.000000
#
# 28 dep 17 | () with p-value 0.000000
#
# 28 dep 18 | () with p-value 0.000003
#
# 28 dep 20 | () with p-value 0.000000
#
# 28 dep 21 | () with p-value 0.000000
#
# 28 dep 23 | () with p-value 0.000000
#
# 28 dep 24 | () with p-value 0.000536
#
# 28 dep 25 | () with p-value 0.000022
#
# 28 dep 27 | () with p-value 0.000000
#
# 28 dep 29 | () with p-value 0.000000
#
# 28 ind 30 | () with p-value 0.940595
#
# 28 dep 31 | () with p-value 0.000000
#
# 28 dep 32 | () with p-value 0.000000
#
# 28 dep 33 | () with p-value 0.000000
#
# 28 dep 34 | () with p-value 0.000000
#
# 28 dep 35 | () with p-value 0.000000
#
# 28 dep 36 | () with p-value 0.000000
#
# 28 dep 37 | () with p-value 0.000000
#
# 28 dep 38 | () with p-value 0.000000
#
# 28 dep 39 | () with p-value 0.000000
#
# 28 dep 40 | () with p-value 0.000000
#
# 28 dep 41 | () with p-value 0.000000
#
# 28 dep 42 | () with p-value 0.000000
#
# 28 dep 43 | () with p-value 0.000000
#
# 28 dep 44 | () with p-value 0.000000
#
# 28 dep 45 | () with p-value 0.000000
#
# 29 dep 0 | () with p-value 0.000000
#
# 29 dep 2 | () with p-value 0.000000
#
# 29 dep 3 | () with p-value 0.000000
#
# 29 dep 4 | () with p-value 0.000046
#
# 29 dep 5 | () with p-value 0.037851
#
# 29 dep 7 | () with p-value 0.000002
#
# 29 dep 8 | () with p-value 0.000000
#
# 29 dep 9 | () with p-value 0.005425
#
# 29 dep 10 | () with p-value 0.000007
#
# 29 dep 11 | () with p-value 0.000000
#
# 29 dep 12 | () with p-value 0.000009
#
# 29 dep 14 | () with p-value 0.000000
#
# 29 dep 15 | () with p-value 0.000000
#
# 29 dep 17 | () with p-value 0.000018
#
# 29 dep 18 | () with p-value 0.000000
#
# 29 dep 19 | () with p-value 0.045001
#
# 29 dep 20 | () with p-value 0.000000
#
# 29 dep 21 | () with p-value 0.000000
#
# 29 dep 23 | () with p-value 0.000000
#
# 29 dep 24 | () with p-value 0.000143
#
# 29 dep 25 | () with p-value 0.000000
#
# 29 dep 27 | () with p-value 0.000000
#
# 29 dep 28 | () with p-value 0.000000
#
# 29 ind 30 | () with p-value 0.385821
#
# 29 dep 31 | () with p-value 0.000000
#
# 29 ind 32 | () with p-value 0.076310
#
# 29 dep 33 | () with p-value 0.000000
#
# 29 dep 34 | () with p-value 0.000000
#
# 29 dep 35 | () with p-value 0.000000
#
# 29 dep 36 | () with p-value 0.000000
#
# 29 dep 37 | () with p-value 0.000000
#
# 29 dep 38 | () with p-value 0.000000
#
# 29 dep 39 | () with p-value 0.000000
#
# 29 dep 40 | () with p-value 0.000000
#
# 29 dep 41 | () with p-value 0.000000
#
# 29 dep 42 | () with p-value 0.000000
#
# 29 dep 43 | () with p-value 0.000000
#
# 29 dep 44 | () with p-value 0.000000
#
# 29 dep 45 | () with p-value 0.000000
#
# 30 ind 31 | () with p-value 0.173750
#
# 30 ind 32 | () with p-value 0.830924
#
# 30 ind 33 | () with p-value 0.885656
#
# 30 ind 34 | () with p-value 0.288420
#
# 30 dep 35 | () with p-value 0.023866
#
# 30 ind 36 | () with p-value 0.541285
#
# 30 ind 37 | () with p-value 0.987555
#
# 30 ind 38 | () with p-value 0.165881
#
# 30 ind 39 | () with p-value 0.653852
#
# 30 ind 40 | () with p-value 0.598313
#
# 30 ind 41 | () with p-value 0.900742
#
# 30 ind 42 | () with p-value 0.276175
#
# 30 ind 43 | () with p-value 0.318603
#
# 30 ind 44 | () with p-value 0.127752
#
# 30 ind 45 | () with p-value 0.174781
#
# 31 dep 0 | () with p-value 0.000000
#
# 31 dep 2 | () with p-value 0.000000
#
# 31 dep 3 | () with p-value 0.000000
#
# 31 dep 4 | () with p-value 0.000000
#
# 31 dep 7 | () with p-value 0.000000
#
# 31 dep 8 | () with p-value 0.000000
#
# 31 dep 10 | () with p-value 0.000000
#
# 31 dep 11 | () with p-value 0.000043
#
# 31 dep 12 | () with p-value 0.000075
#
# 31 dep 14 | () with p-value 0.000006
#
# 31 dep 15 | () with p-value 0.000035
#
# 31 dep 17 | () with p-value 0.000000
#
# 31 dep 18 | () with p-value 0.000000
#
# 31 dep 19 | () with p-value 0.000000
#
# 31 dep 20 | () with p-value 0.000000
#
# 31 dep 21 | () with p-value 0.000000
#
# 31 dep 23 | () with p-value 0.000000
#
# 31 dep 24 | () with p-value 0.000000
#
# 31 dep 25 | () with p-value 0.004711
#
# 31 dep 26 | () with p-value 0.000000
#
# 31 dep 27 | () with p-value 0.000000
#
# 31 dep 28 | () with p-value 0.000000
#
# 31 dep 29 | () with p-value 0.000000
#
# 31 dep 32 | () with p-value 0.000000
#
# 31 dep 33 | () with p-value 0.000000
#
# 31 dep 34 | () with p-value 0.000226
#
# 31 dep 35 | () with p-value 0.000000
#
# 31 dep 36 | () with p-value 0.000000
#
# 31 dep 37 | () with p-value 0.000000
#
# 31 dep 38 | () with p-value 0.000018
#
# 31 dep 39 | () with p-value 0.000000
#
# 31 dep 40 | () with p-value 0.000134
#
# 31 dep 41 | () with p-value 0.000000
#
# 31 dep 42 | () with p-value 0.000000
#
# 31 dep 43 | () with p-value 0.000000
#
# 31 dep 44 | () with p-value 0.000000
#
# 31 dep 45 | () with p-value 0.000000
#
# 32 dep 0 | () with p-value 0.000000
#
# 32 dep 2 | () with p-value 0.000000
#
# 32 dep 3 | () with p-value 0.000000
#
# 32 dep 4 | () with p-value 0.000000
#
# 32 dep 5 | () with p-value 0.006291
#
# 32 dep 7 | () with p-value 0.000040
#
# 32 dep 8 | () with p-value 0.000000
#
# 32 dep 10 | () with p-value 0.000000
#
# 32 dep 11 | () with p-value 0.000000
#
# 32 dep 12 | () with p-value 0.000008
#
# 32 dep 14 | () with p-value 0.027471
#
# 32 dep 15 | () with p-value 0.029320
#
# 32 dep 16 | () with p-value 0.009931
#
# 32 dep 17 | () with p-value 0.000000
#
# 32 dep 18 | () with p-value 0.000000
#
# 32 dep 19 | () with p-value 0.000000
#
# 32 dep 20 | () with p-value 0.000000
#
# 32 dep 21 | () with p-value 0.000000
#
# 32 dep 23 | () with p-value 0.000000
#
# 32 dep 24 | () with p-value 0.000000
#
# 32 dep 25 | () with p-value 0.000150
#
# 32 dep 26 | () with p-value 0.000006
#
# 32 dep 27 | () with p-value 0.000000
#
# 32 dep 28 | () with p-value 0.000000
#
# 32 dep 31 | () with p-value 0.000000
#
# 32 dep 33 | () with p-value 0.000000
#
# 32 dep 34 | () with p-value 0.037148
#
# 32 dep 35 | () with p-value 0.000000
#
# 32 dep 36 | () with p-value 0.000000
#
# 32 dep 37 | () with p-value 0.000000
#
# 32 dep 38 | () with p-value 0.000000
#
# 32 dep 39 | () with p-value 0.000000
#
# 32 dep 40 | () with p-value 0.000007
#
# 32 dep 41 | () with p-value 0.000000
#
# 32 dep 42 | () with p-value 0.000000
#
# 32 dep 43 | () with p-value 0.000000
#
# 32 dep 44 | () with p-value 0.000000
#
# 32 dep 45 | () with p-value 0.006034
#
# ...
#
# 17 dep 41 | (18,) with p-value 0.000080
#
# 17 dep 41 | (19,) with p-value 0.000000
#
# 17 dep 41 | (20,) with p-value 0.000000
#
# 17 dep 41 | (21,) with p-value 0.000010
#
# 17 dep 41 | (23,) with p-value 0.000000
#
# 17 dep 41 | (24,) with p-value 0.000000
#
# 17 dep 41 | (26,) with p-value 0.000000
#
# 17 dep 41 | (27,) with p-value 0.000002
#
# 17 dep 41 | (28,) with p-value 0.000000
#
# 17 dep 41 | (29,) with p-value 0.000000
#
# 17 dep 41 | (31,) with p-value 0.000091
#
# 17 dep 41 | (32,) with p-value 0.000025
#
# 17 dep 41 | (33,) with p-value 0.000007
#
# 17 dep 41 | (35,) with p-value 0.000043
#
# 17 dep 41 | (36,) with p-value 0.000000
#
# 17 ind 41 | (37,) with p-value 0.112351
#
# 17 dep 42 | (0,) with p-value 0.000000
#
# 17 dep 42 | (3,) with p-value 0.000000
#
# 17 dep 42 | (8,) with p-value 0.000000
#
# 17 dep 42 | (10,) with p-value 0.000000
#
# 17 dep 42 | (18,) with p-value 0.000000
#
# 17 dep 42 | (19,) with p-value 0.000000
#
# 17 dep 42 | (20,) with p-value 0.000000
#
# 17 dep 42 | (21,) with p-value 0.000000
#
# 17 dep 42 | (23,) with p-value 0.000000
#
# 17 dep 42 | (24,) with p-value 0.000000
#
# 17 dep 42 | (26,) with p-value 0.000000
#
# 17 dep 42 | (27,) with p-value 0.000000
#
# 17 dep 42 | (28,) with p-value 0.000000
#
# 17 dep 42 | (29,) with p-value 0.000000
#
# 17 dep 42 | (31,) with p-value 0.000000
#
# 17 dep 42 | (32,) with p-value 0.000000
#
# 17 dep 42 | (33,) with p-value 0.000000
#
# 17 dep 42 | (35,) with p-value 0.000000
#
# 17 dep 42 | (36,) with p-value 0.000000
#
# 17 dep 42 | (37,) with p-value 0.000006
#
# 17 dep 42 | (38,) with p-value 0.000000
#
# 17 dep 42 | (39,) with p-value 0.000000
#
# 17 dep 42 | (40,) with p-value 0.000000
#
# 17 dep 42 | (41,) with p-value 0.000000
#
# 17 dep 42 | (43,) with p-value 0.000000
#
# 17 dep 42 | (44,) with p-value 0.000000
#
# 17 dep 42 | (45,) with p-value 0.000000
#
# 17 dep 43 | (0,) with p-value 0.000000
#
# 17 dep 43 | (3,) with p-value 0.000000
#
# 17 dep 43 | (8,) with p-value 0.000000
#
# 17 dep 43 | (10,) with p-value 0.000000
#
# 17 dep 43 | (18,) with p-value 0.000000
#
# 17 dep 43 | (19,) with p-value 0.000000
#
# 17 dep 43 | (20,) with p-value 0.000000
#
# 17 dep 43 | (21,) with p-value 0.000000
#
# 17 dep 43 | (23,) with p-value 0.000000
#
# 17 dep 43 | (24,) with p-value 0.000000
#
# 17 dep 43 | (26,) with p-value 0.000000
#
# 17 dep 43 | (27,) with p-value 0.000000
#
# 17 dep 43 | (28,) with p-value 0.000000
#
# 17 dep 43 | (29,) with p-value 0.000000
#
# 17 dep 43 | (31,) with p-value 0.000000
#
# 17 dep 43 | (32,) with p-value 0.000000
#
# 17 dep 43 | (33,) with p-value 0.000000
#
# 17 dep 43 | (35,) with p-value 0.000000
#
# 17 dep 43 | (36,) with p-value 0.000000
#
# 17 dep 43 | (37,) with p-value 0.000000
#
# 17 dep 43 | (38,) with p-value 0.000000
#
# 17 dep 43 | (39,) with p-value 0.000000
#
# 17 dep 43 | (40,) with p-value 0.000000
#
# 17 dep 43 | (41,) with p-value 0.000000
#
# 17 dep 43 | (42,) with p-value 0.000000
#
# 17 dep 43 | (44,) with p-value 0.000000
#
# 17 dep 43 | (45,) with p-value 0.000000
#
# 17 dep 44 | (0,) with p-value 0.000000
#
# 17 dep 44 | (3,) with p-value 0.000002
#
# 17 dep 44 | (8,) with p-value 0.000237
#
# 17 dep 44 | (10,) with p-value 0.000004
#
# 17 dep 44 | (18,) with p-value 0.000034
#
# 17 dep 44 | (19,) with p-value 0.000000
#
# 17 dep 44 | (20,) with p-value 0.000045
#
# 17 dep 44 | (21,) with p-value 0.000354
#
# 17 dep 44 | (23,) with p-value 0.000004
#
# 17 dep 44 | (24,) with p-value 0.000000
#
# 17 dep 44 | (26,) with p-value 0.000000
#
# 17 dep 44 | (27,) with p-value 0.000068
#
# 17 dep 44 | (28,) with p-value 0.000006
#
# 17 dep 44 | (29,) with p-value 0.000001
#
# 17 dep 44 | (31,) with p-value 0.000547
#
# 17 dep 44 | (32,) with p-value 0.012192
#
# 17 dep 44 | (33,) with p-value 0.000059
#
# 17 dep 44 | (35,) with p-value 0.012371
#
# 17 dep 44 | (36,) with p-value 0.000005
#
# 17 ind 44 | (37,) with p-value 0.814101
#
# 17 dep 45 | (0,) with p-value 0.017634
#
# 17 dep 45 | (3,) with p-value 0.016904
#
# 17 dep 45 | (8,) with p-value 0.025662
#
# 17 dep 45 | (10,) with p-value 0.005079
#
# 17 ind 45 | (18,) with p-value 0.191348
#
# 18 dep 0 | (2,) with p-value 0.000000
#
# 18 dep 0 | (3,) with p-value 0.000000
#
# 18 dep 0 | (4,) with p-value 0.000000
#
# 18 dep 0 | (8,) with p-value 0.000000
#
# 18 dep 0 | (10,) with p-value 0.000000
#
# 18 dep 0 | (17,) with p-value 0.000000
#
# 18 dep 0 | (19,) with p-value 0.000000
#
# 18 dep 0 | (20,) with p-value 0.000000
#
# 18 dep 0 | (21,) with p-value 0.000000
#
# 18 dep 0 | (23,) with p-value 0.000000
#
# 18 dep 0 | (24,) with p-value 0.000000
#
# 18 dep 0 | (25,) with p-value 0.000000
#
# 18 dep 0 | (26,) with p-value 0.000000
#
# 18 dep 0 | (27,) with p-value 0.000000
#
# 18 dep 0 | (28,) with p-value 0.000000
#
# 18 dep 0 | (29,) with p-value 0.000000
#
# 18 dep 0 | (31,) with p-value 0.000000
#
# 18 dep 0 | (32,) with p-value 0.000000
#
# 18 dep 0 | (33,) with p-value 0.000000
#
# 18 dep 0 | (34,) with p-value 0.000000
#
# 18 dep 0 | (35,) with p-value 0.000000
#
# 18 dep 0 | (36,) with p-value 0.000000
#
# 18 dep 0 | (37,) with p-value 0.000188
#
# 18 dep 0 | (38,) with p-value 0.000000
#
# 18 dep 0 | (39,) with p-value 0.000000
#
# 18 dep 0 | (40,) with p-value 0.000000
#
# 18 dep 0 | (41,) with p-value 0.000000
#
# 18 dep 0 | (42,) with p-value 0.000000
#
# 18 dep 0 | (43,) with p-value 0.000000
#
# 18 dep 0 | (44,) with p-value 0.000000
#
# 18 dep 0 | (45,) with p-value 0.000000
#
# 18 dep 2 | (0,) with p-value 0.000000
#
# 18 dep 2 | (3,) with p-value 0.000000
#
# 18 dep 2 | (4,) with p-value 0.000000
#
# 18 dep 2 | (8,) with p-value 0.000000
#
# 18 dep 2 | (10,) with p-value 0.000000
#
# 18 dep 2 | (17,) with p-value 0.000000
#
# 18 dep 2 | (19,) with p-value 0.000000
#
# 18 dep 2 | (20,) with p-value 0.000000
#
# 18 dep 2 | (21,) with p-value 0.000000
#
# 18 dep 2 | (23,) with p-value 0.000000
#
# 18 dep 2 | (24,) with p-value 0.000000
#
# 18 dep 2 | (25,) with p-value 0.000000
#
# 18 dep 2 | (26,) with p-value 0.000000
#
# 18 dep 2 | (27,) with p-value 0.000000
#
# 18 dep 2 | (28,) with p-value 0.000000
#
# 18 dep 2 | (29,) with p-value 0.000000
#
# 18 dep 2 | (31,) with p-value 0.000000
#
# 18 dep 2 | (32,) with p-value 0.000000
#
# 18 dep 2 | (33,) with p-value 0.000000
#
# 18 dep 2 | (34,) with p-value 0.000000
#
# 18 dep 2 | (35,) with p-value 0.000000
#
# 18 dep 2 | (36,) with p-value 0.000000
#
# 18 dep 2 | (37,) with p-value 0.000000
#
# 18 dep 2 | (38,) with p-value 0.000000
#
# 18 dep 2 | (39,) with p-value 0.000000
#
# 18 dep 2 | (40,) with p-value 0.000000
#
# 18 dep 2 | (41,) with p-value 0.000000
#
# 18 dep 2 | (42,) with p-value 0.000000
#
# 18 dep 2 | (43,) with p-value 0.000000
#
# 18 dep 2 | (44,) with p-value 0.000000
#
# 18 dep 2 | (45,) with p-value 0.000000
#
# 18 dep 3 | (0,) with p-value 0.000000
#
# 18 dep 3 | (2,) with p-value 0.000000
#
# 18 dep 3 | (4,) with p-value 0.000000
#
# 18 dep 3 | (8,) with p-value 0.000000
#
# 18 dep 3 | (10,) with p-value 0.000000
#
# 18 dep 3 | (17,) with p-value 0.000000
#
# 18 dep 3 | (19,) with p-value 0.000000
#
# 18 dep 3 | (20,) with p-value 0.000000
#
# 18 dep 3 | (21,) with p-value 0.000000
#
# 18 dep 3 | (23,) with p-value 0.000000
#
# 18 dep 3 | (24,) with p-value 0.000000
#
# 18 dep 3 | (25,) with p-value 0.000000
#
# 18 dep 3 | (26,) with p-value 0.000000
#
# 18 dep 3 | (27,) with p-value 0.000000
#
# 18 dep 3 | (28,) with p-value 0.000000
#
# 18 dep 3 | (29,) with p-value 0.000000
#
# 18 dep 3 | (31,) with p-value 0.000000
#
# 18 dep 3 | (32,) with p-value 0.000000
#
# 18 dep 3 | (33,) with p-value 0.000000
#
# 18 dep 3 | (34,) with p-value 0.000000
#
# 18 dep 3 | (35,) with p-value 0.000000
#
# 18 dep 3 | (36,) with p-value 0.000000
#
# 18 dep 3 | (37,) with p-value 0.000000
#
# 18 dep 3 | (38,) with p-value 0.000000
#
# 18 dep 3 | (39,) with p-value 0.000000
#
# 18 dep 3 | (40,) with p-value 0.000000
#
# 18 dep 3 | (41,) with p-value 0.000000
#
# 18 dep 3 | (42,) with p-value 0.000000
#
# 18 dep 3 | (43,) with p-value 0.000000
#
# 18 dep 3 | (44,) with p-value 0.000000
#
# 18 dep 3 | (45,) with p-value 0.000000
#
# 18 dep 4 | (0,) with p-value 0.000000
#
# 18 dep 4 | (2,) with p-value 0.000001
#
# 18 dep 4 | (3,) with p-value 0.000001
#
# 18 dep 4 | (8,) with p-value 0.000000
#
# 18 dep 4 | (10,) with p-value 0.003215
#
# 18 dep 4 | (17,) with p-value 0.000000
#
# 18 dep 4 | (19,) with p-value 0.000000
#
# 18 dep 4 | (20,) with p-value 0.000000
#
# 18 dep 4 | (21,) with p-value 0.000000
#
# 18 dep 4 | (23,) with p-value 0.000000
#
# 18 dep 4 | (24,) with p-value 0.000000
#
# 18 dep 4 | (25,) with p-value 0.000000
#
# 18 dep 4 | (26,) with p-value 0.000000
#
# 18 dep 4 | (27,) with p-value 0.000000
#
# 18 dep 4 | (28,) with p-value 0.000000
#
# 18 dep 4 | (29,) with p-value 0.000000
#
# 18 dep 4 | (31,) with p-value 0.000000
#
# 18 dep 4 | (32,) with p-value 0.000000
#
# 18 dep 4 | (33,) with p-value 0.000000
#
# 18 dep 4 | (34,) with p-value 0.000000
#
# 18 dep 4 | (35,) with p-value 0.000000
#
# 18 dep 4 | (36,) with p-value 0.000000
#
# 18 dep 4 | (37,) with p-value 0.000015
#
# 18 dep 4 | (38,) with p-value 0.000000
#
# 18 dep 4 | (39,) with p-value 0.000000
#
# 18 dep 4 | (40,) with p-value 0.000000
#
# 18 dep 4 | (41,) with p-value 0.000000
#
# 18 dep 4 | (42,) with p-value 0.000000
#
# 18 dep 4 | (43,) with p-value 0.000003
#
# 18 dep 4 | (44,) with p-value 0.000000
#
# 18 dep 4 | (45,) with p-value 0.000000
#
# 18 dep 8 | (0,) with p-value 0.000000
#
# 18 dep 8 | (2,) with p-value 0.000000
#
# 18 dep 8 | (3,) with p-value 0.000000
#
# 18 dep 8 | (4,) with p-value 0.000000
#
# 18 dep 8 | (10,) with p-value 0.000000
#
# 18 dep 8 | (17,) with p-value 0.000000
#
# 18 dep 8 | (19,) with p-value 0.000000
#
# 18 dep 8 | (20,) with p-value 0.000000
#
# 18 dep 8 | (21,) with p-value 0.000000
#
# 18 dep 8 | (23,) with p-value 0.000000
#
# 18 dep 8 | (24,) with p-value 0.000000
#
# 18 dep 8 | (25,) with p-value 0.000000
#
# 18 dep 8 | (26,) with p-value 0.000000
#
# 18 dep 8 | (27,) with p-value 0.000000
#
# 18 dep 8 | (28,) with p-value 0.000000
#
# 18 dep 8 | (29,) with p-value 0.000000
#
# 18 dep 8 | (31,) with p-value 0.000000
#
# 18 dep 8 | (32,) with p-value 0.000000
#
# 18 dep 8 | (33,) with p-value 0.000000
#
# 18 dep 8 | (34,) with p-value 0.000000
#
# 18 dep 8 | (35,) with p-value 0.000000
#
# 18 dep 8 | (36,) with p-value 0.000000
#
# 18 dep 8 | (37,) with p-value 0.000248
#
# 18 dep 8 | (38,) with p-value 0.000000
#
# 18 dep 8 | (39,) with p-value 0.000000
#
# 18 dep 8 | (40,) with p-value 0.000000
#
# 18 dep 8 | (41,) with p-value 0.000000
#
# 18 dep 8 | (42,) with p-value 0.000000
#
# 18 dep 8 | (43,) with p-value 0.000000
#
# 18 dep 8 | (44,) with p-value 0.000000
#
# 18 dep 8 | (45,) with p-value 0.000000
#
# 18 dep 10 | (0,) with p-value 0.000000
#
# 18 dep 10 | (2,) with p-value 0.000000
#
# 18 dep 10 | (3,) with p-value 0.000000
#
# 18 dep 10 | (4,) with p-value 0.000000
#
# 18 dep 10 | (8,) with p-value 0.000000
#
# 18 dep 10 | (17,) with p-value 0.000000
#
# 18 dep 10 | (19,) with p-value 0.000000
#
# 18 dep 10 | (20,) with p-value 0.000000
#
# 18 dep 10 | (21,) with p-value 0.000000
#
# 18 dep 10 | (23,) with p-value 0.000000
#
# 18 dep 10 | (24,) with p-value 0.000000
#
# 18 dep 10 | (25,) with p-value 0.000000
#
# 18 dep 10 | (26,) with p-value 0.000000
#
# 18 dep 10 | (27,) with p-value 0.000000
#
# 18 dep 10 | (28,) with p-value 0.000000
#
# 18 dep 10 | (29,) with p-value 0.000000
#
# 18 dep 10 | (31,) with p-value 0.000000
#
# 18 dep 10 | (32,) with p-value 0.000000
#
# 18 dep 10 | (33,) with p-value 0.000000
#
# 18 dep 10 | (34,) with p-value 0.000000
#
# 18 dep 10 | (35,) with p-value 0.000000
#
# 18 dep 10 | (36,) with p-value 0.000000
#
# 18 dep 10 | (37,) with p-value 0.000066
#
# 18 dep 10 | (38,) with p-value 0.000000
#
# 18 dep 10 | (39,) with p-value 0.000000
#
# 18 dep 10 | (40,) with p-value 0.000000
#
# 18 dep 10 | (41,) with p-value 0.000000
#
# 18 dep 10 | (42,) with p-value 0.000000
#
# 18 dep 10 | (43,) with p-value 0.000000
#
# 18 dep 10 | (44,) with p-value 0.000000
#
# 18 dep 10 | (45,) with p-value 0.000000
#
# 18 dep 17 | (0,) with p-value 0.000000
#
# 18 dep 17 | (2,) with p-value 0.000000
#
# 18 dep 17 | (3,) with p-value 0.000000
#
# 18 dep 17 | (4,) with p-value 0.000000
#
# 18 dep 17 | (8,) with p-value 0.000000
#
# 18 dep 17 | (10,) with p-value 0.000000
#
# 18 dep 17 | (19,) with p-value 0.000000
#
# 18 dep 17 | (20,) with p-value 0.000000
#
# 18 dep 17 | (21,) with p-value 0.000000
#
# 18 dep 17 | (23,) with p-value 0.000000
#
# 18 dep 17 | (24,) with p-value 0.000000
#
# 18 dep 17 | (25,) with p-value 0.000000
#
# 18 dep 17 | (26,) with p-value 0.000000
#
# 18 dep 17 | (27,) with p-value 0.000000
#
# 18 dep 17 | (28,) with p-value 0.000000
#
# 18 dep 17 | (29,) with p-value 0.000000
#
# 18 dep 17 | (31,) with p-value 0.000000
#
# 18 dep 17 | (32,) with p-value 0.000000
#
# 18 dep 17 | (33,) with p-value 0.000000
#
# 18 dep 17 | (34,) with p-value 0.000000
#
# 18 dep 17 | (35,) with p-value 0.000000
#
# 18 dep 17 | (36,) with p-value 0.000000
#
# 18 dep 17 | (37,) with p-value 0.000000
#
# 18 dep 17 | (38,) with p-value 0.000000
#
# 18 dep 17 | (39,) with p-value 0.000000
#
# 18 dep 17 | (40,) with p-value 0.000000
#
# 18 dep 17 | (41,) with p-value 0.000000
#
# 18 dep 17 | (42,) with p-value 0.000000
#
# 18 dep 17 | (43,) with p-value 0.000000
#
# 18 dep 17 | (44,) with p-value 0.000000
#
# 18 dep 17 | (45,) with p-value 0.000000
#
# 18 dep 19 | (0,) with p-value 0.000000
#
# 18 dep 19 | (2,) with p-value 0.000001
#
# 18 dep 19 | (3,) with p-value 0.001337
#
# 18 dep 19 | (4,) with p-value 0.000000
#
# 18 dep 19 | (8,) with p-value 0.000000
#
# 18 dep 19 | (10,) with p-value 0.000000
#
# 18 dep 19 | (17,) with p-value 0.000104
#
# 18 dep 19 | (20,) with p-value 0.000000
#
# 18 dep 19 | (21,) with p-value 0.000000
#
# 18 dep 19 | (23,) with p-value 0.000000
#
# 18 dep 19 | (24,) with p-value 0.000000
#
# 18 dep 19 | (25,) with p-value 0.000000
#
# 18 dep 19 | (26,) with p-value 0.000000
#
# 18 dep 19 | (27,) with p-value 0.000000
#
# 18 dep 19 | (28,) with p-value 0.000000
#
# 18 dep 19 | (29,) with p-value 0.000000
#
# 18 dep 19 | (31,) with p-value 0.000017
#
# 18 dep 19 | (32,) with p-value 0.000000
#
# 18 dep 19 | (33,) with p-value 0.000000
#
# 18 dep 19 | (34,) with p-value 0.000000
#
# 18 dep 19 | (35,) with p-value 0.000000
#
# 18 dep 19 | (36,) with p-value 0.000000
#
# 18 dep 19 | (37,) with p-value 0.000633
#
# 18 dep 19 | (38,) with p-value 0.000000
#
# 18 dep 19 | (39,) with p-value 0.000000
#
# 18 dep 19 | (40,) with p-value 0.000000
#
# 18 dep 19 | (41,) with p-value 0.000000
#
# 18 dep 19 | (42,) with p-value 0.000000
#
# 18 dep 19 | (43,) with p-value 0.003340
#
# 18 dep 19 | (44,) with p-value 0.000000
#
# 18 dep 19 | (45,) with p-value 0.000000
#
# 18 dep 20 | (0,) with p-value 0.000000
#
# 18 dep 20 | (2,) with p-value 0.000237
#
# 18 dep 20 | (3,) with p-value 0.000000
#
# 18 dep 20 | (4,) with p-value 0.000000
#
# 18 dep 20 | (8,) with p-value 0.000000
#
# 18 dep 20 | (10,) with p-value 0.000000
#
# 18 dep 20 | (17,) with p-value 0.000000
#
# 18 dep 20 | (19,) with p-value 0.000000
#
# 18 dep 20 | (21,) with p-value 0.000000
#
# 18 dep 20 | (23,) with p-value 0.000000
#
# 18 dep 20 | (24,) with p-value 0.000000
#
# 18 dep 20 | (25,) with p-value 0.000000
#
# 18 dep 20 | (26,) with p-value 0.000000
#
# 18 dep 20 | (27,) with p-value 0.000000
#
# 18 dep 20 | (28,) with p-value 0.000000
#
# 18 dep 20 | (29,) with p-value 0.000000
#
# 18 dep 20 | (31,) with p-value 0.000000
#
# 18 dep 20 | (32,) with p-value 0.000001
#
# 18 dep 20 | (33,) with p-value 0.000000
#
# 18 dep 20 | (34,) with p-value 0.000000
#
# 18 dep 20 | (35,) with p-value 0.000000
#
# 18 dep 20 | (36,) with p-value 0.000000
#
# 18 ind 20 | (37,) with p-value 0.793738
#
# 18 dep 21 | (0,) with p-value 0.000000
#
# 18 dep 21 | (2,) with p-value 0.000000
#
# 18 dep 21 | (3,) with p-value 0.000000
#
# 18 dep 21 | (4,) with p-value 0.000000
#
# 18 dep 21 | (8,) with p-value 0.000000
#
# 18 dep 21 | (10,) with p-value 0.000000
#
# 18 dep 21 | (17,) with p-value 0.000000
#
# 18 dep 21 | (19,) with p-value 0.000000
#
# 18 dep 21 | (20,) with p-value 0.000000
#
# 18 dep 21 | (23,) with p-value 0.000000
#
# 18 dep 21 | (24,) with p-value 0.000000
#
# 18 dep 21 | (25,) with p-value 0.000000
#
# 18 dep 21 | (26,) with p-value 0.000000
#
# 18 dep 21 | (27,) with p-value 0.000000
#
# 18 dep 21 | (28,) with p-value 0.000000
#
# 18 dep 21 | (29,) with p-value 0.000000
#
# 18 dep 21 | (31,) with p-value 0.000000
#
# 18 dep 21 | (32,) with p-value 0.000000
#
# 18 dep 21 | (33,) with p-value 0.000000
#
# 18 dep 21 | (34,) with p-value 0.000000
#
# 18 dep 21 | (35,) with p-value 0.000000
#
# 18 dep 21 | (36,) with p-value 0.000000
#
# 18 ind 21 | (37,) with p-value 0.103900
#
# 18 dep 23 | (0,) with p-value 0.000000
#
# 18 dep 23 | (2,) with p-value 0.000023
#
# 18 dep 23 | (3,) with p-value 0.000000
#
# 18 dep 23 | (4,) with p-value 0.000000
#
# 18 dep 23 | (8,) with p-value 0.000002
#
# 18 dep 23 | (10,) with p-value 0.000000

# %%
hts_res_dict = {}
for experiment in range(0,4):
    with open(f"../data/fault_data/cp_fault_{experiment}.pkl", "rb") as f:
        s_list, X = pickle.load(f)
    ind = 0
    mapping = {}
    for service in s_list:
        x = service.split('-')
        x = x[:-2]
        x = '-'.join(x)
        mapping[ind] = x
        ind+=1
    # Start CausalRCA
    start_time = time.time()
    X = np.diff(X,axis=0)
    X = normalize(X,axis=0)
    cg = pc(X, 0.05, fisherz, False, 0, -1, verbose=True)
    adj = cg.G.graph
    pagerank = PageRank()
    scores = pagerank.fit_predict(adj.T)
    combined_pagerank = defaultdict(float)
    for service_id in range(len(scores)):
        combined_pagerank[mapping[service_id]] += scores[service_id]
    
    combined_pagerank_df = pd.DataFrame(
                list(combined_pagerank.items()), columns=["Service Type", "Combined Frequency"]
    )
    end_time = time.time()
    ####
    
    t_elapsed = end_time - start_time
    sorted_pr = combined_pagerank_df.sort_values(by="Combined Frequency", ascending=False)
    top_5 = list(sorted_pr.head(5)["Service Type"])
    hts_res_dict[experiment] = (top_5, t_elapsed)
